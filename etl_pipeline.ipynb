# %%
import pandas as pd
import re

def create_unique_id_generator():
    """Функция для создания глобального генератора."""
    counter = 1
    while True:
        yield counter
        counter += 1

def get_ids_for_empty_name(value, id_generator):
    if value == "":
        return f"anon_{next(id_generator)}"
    else:
        return value

def transform_work_list(work_list):
    work_list = work_list.strip("[]")
    parsed_list = [item.strip() for item in work_list.split(",")]
    сompanies_num = parsed_list.count("Компания")
    freelance_num = parsed_list.count("Фриланс")
    total_num = сompanies_num + freelance_num
    works_info = [
        {
            "name": parsed_list[total_num + i],
            "post": parsed_list[total_num * 2 + i],
            "salary": parsed_list[total_num * 3 + i]
        } if total_num * 3 + i < len(parsed_list) and parsed_list[total_num * 3 + i] != "" else
        {
            "name": parsed_list[total_num + i],
            "post": parsed_list[total_num * 2 + i],
            "salary": None
        }
        for i in range(total_num)
    ]
    return works_info

def get_data_from_file(file_path: str) -> pd.DataFrame:
    unique_id_generator = create_unique_id_generator()
    data = pd.read_excel(
        file_path,
        converters={
            "ФИО": lambda x: get_ids_for_empty_name(x, unique_id_generator),
        }
    )
    data["Где работал"] = data["Где работал"].map(transform_work_list)
    return data

# %%
data = get_data_from_file("yandex form 2.xlsx")

# %%
data
# Out:
#                   Дата                            ФИО  Год выпуска Матпоток  \
# 0  2024-09-09 22:58:28     Евглевская Анна Васильевна         2019       Да
# 1  2024-09-09 22:47:47    Карпенко Мария Владимировна         2019       Да
# 2  2024-09-09 22:51:59       Рябова Светлана Олеговна         2019       Да
# 3  2024-09-09 22:53:10  Громова Надежда (дев. Родина)         2019       Да
# 4  2024-09-09 23:32:30  Самойлов Никита Александрович         2016       Да
# ..                 ...                            ...          ...      ...
# 83 2024-09-25 18:47:00                        anon_20         2020       Да
# 84 2024-09-25 20:46:00                        anon_21         2020       Да
# 85 2024-09-26 14:16:00                        anon_22         2017       Да
# 86 2024-09-26 22:30:00     Кунякин Виктор Геннадьевич         2019      Нет
# 87 2024-09-29 10:13:00        Флоря Мария Евгеньевна          2018       Да
#
#                                          Магистратура  \
# 0                                             [Нет,,]
# 1                                             [Нет,,]
# 2   [Да,New Mexico Highlands University ,Computer ...
# 3                                             [Нет,,]
# 4     [Да,СПбГЭУ,Прикладная математика и информатика]
# ..                                                ...
# 83             [Да,СПБГЭУ, Анализ данных в экономике]
# 84                                           [Нет,, ]
# 85                                      [Да,СПбГЭУ, ]
# 86                                           [Нет,, ]
# 87                                      [Да,СПбГЭУ, ]
#
#                                           Где работал  \
# 0   [{'name': 'SGS Vostok Limited', 'post': 'Бизне...
# 1   [{'name': 'Яндекс', 'post': 'Старший разработч...
# 2   [{'name': 'University at Buffalo', 'post': 'Ас...
# 3   [{'name': 'ООО «СКТ Групп»', 'post': 'Специали...
# 4   [{'name': 'ПАО "Газпром нефть"', 'post': 'Руко...
# ..                                                ...
# 83  [{'name': 'ООО Райдер Софт', 'post': 'Менеджер...
# 84  [{'name': 'ПАО "Газпром нефть"', 'post': 'BI а...
# 85  [{'name': 'РСТИ', 'post': 'Аналитик', 'salary'...
# 86  [{'name': 'Vattenfall Energy Trading', 'post':...
# 87  [{'name': 'Пивоваренная компания «Балтика»', '...
#
#                                          Сферы работы  \
# 0   Разработка прикладного программного обеспечени...
# 1     Разработка прикладного программного обеспечения
# 2    Оптимизационные задачи,Задачи машинного обучения
# 3         Оптимизационные задачи,Экономический анализ
# 4   Разработка прикладного программного обеспечени...
# ..                                                ...
# 83                       Экономический анализ, Другое
# 84                                             Другое
# 85  Оптимизационные задачи, Экономический анализ, ...
# 86                               Экономический анализ
# 87  Оптимизационные задачи, Экономический анализ, ...
#
#                                          Другие сферы
# 0                        Анализ данных и визуализация
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 83                                                NaN
# 84  Анализ данных, etl процессы, построение отчетн...
# 85  Организация бизнес процессов, внедрение програ...
# 86                                                NaN
# 87                                    Прогнозирование
#
# [88 rows x 8 columns]

# %%
def parse_mean_salary(salary):
    if salary is None:
        return None
    numbers = [int(num.replace(" ", "")) for num in re.findall(r"\d+\s?\d*", salary)]
    if len(numbers) == 2:
        return sum(numbers) / 2
    elif len(numbers) == 1:
        return numbers[0]
    else:
        return None

# %%
def parse_magistracy(magistracy):
    magistracy = magistracy.strip("[]")
    magistracy = [item.strip() for item in magistracy.split(",")]
    return magistracy

def flatten_data(data: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for idx, row in data.iterrows():
        for step, job in enumerate(row["Где работал"]):
            rows.append({
                "graduate": idx,
                "step": step,
                "company": job["name"],
                "position": job["post"],
                "salary": job["salary"],
                "graduation_year": row["Год выпуска"],
                "math_group": row["Матпоток"],
                "magistracy": parse_magistracy(row["Магистратура"])
                # "salary_mean": parse_mean_salary(job["salary"])
            })
    data = pd.DataFrame(rows)
    # data["salary_mean"] = (
    #     data.groupby("person_id")["salary_mean"]
    #           .transform(lambda group: group.ffill().bfill())
    # )

    data = data.sort_values(by=["step"])

    # data["current_salary"] = data.groupby("person_id")["salary_interval"].transform("last")
    # data = data.sort_values("current_salary")

    data = data.sort_values(by=["graduate", "step"])

    return data

# %%
data = flatten_data(data)
data
# Out:
#      graduate  step                          company                 position  \
# 0           0     0               SGS Vostok Limited          Бизнес-аналитик
# 1           0     1                            Devim  Старший бизнес-аналитик
# 2           0     2                       S&P Global                  Analyst
# 3           1     0                           Яндекс      Старший разработчик
# 4           2     0            University at Buffalo                 Аспирант
# ..        ...   ...                              ...                      ...
# 137        84     2          Т-банк Центр Разработки      Старший BI аналитик
# 138        85     0                             РСТИ                 Аналитик
# 139        86     0        Vattenfall Energy Trading    Junior Options Trader
# 140        87     0  Пивоваренная компания «Балтика»            Demand planer
# 141        87     1              ООО Мултон Партнерс            Demand planer
#
#                           salary  graduation_year math_group  \
# 0     50 000 руб. — 100 000 руб.             2019         Да
# 1    150 000 руб. — 200 000 руб.             2019         Да
# 2    300 000 руб. — 350 000 руб.             2019         Да
# 3             Более 400 000 руб.             2019         Да
# 4                           None             2019         Да
# ..                           ...              ...        ...
# 137  200 000 руб. — 250 000 руб.             2020         Да
# 138  200 000 руб. — 250 000 руб.             2017         Да
# 139           Более 400 000 руб.             2019        Нет
# 140  100 000 руб. — 150 000 руб.             2018         Да
# 141  150 000 руб. — 200 000 руб.             2018         Да
#
#                                             magistracy
# 0                                            [Нет, , ]
# 1                                            [Нет, , ]
# 2                                            [Нет, , ]
# 3                                            [Нет, , ]
# 4    [Да, New Mexico Highlands University, Computer...
# ..                                                 ...
# 137                                          [Нет, , ]
# 138                                     [Да, СПбГЭУ, ]
# 139                                          [Нет, , ]
# 140                                     [Да, СПбГЭУ, ]
# 141                                     [Да, СПбГЭУ, ]
#
# [142 rows x 8 columns]

# %%
def get_magistracy(x):
    if x[1] == "СПбГЭУ" and any([(substring in x[2].lower())
    for substring in ["пм", "прикладная математика", "анализ данных"]]):
        return "Магистратура ПМ СПбГЭУ"
    elif x[0] == "Да":
        return "Другая магистратура"
    else:
        return "Без магистратуры"

# %%
data["magistracy"] = data["magistracy"].map(get_magistracy)

# %%
data.rename(
    {"salary": "salary_range"},
    axis=1,
    inplace=True
)

# %%
import sqlite3
cnx = sqlite3.connect('graduates.db')

# %%
data.to_sql(name="graduates", con=cnx, index=False)
# Out:
# 142

# %%
data
# Out:
#      graduate  step                          company                 position  \
# 0           0     0               SGS Vostok Limited          Бизнес-аналитик
# 1           0     1                            Devim  Старший бизнес-аналитик
# 2           0     2                       S&P Global                  Analyst
# 3           1     0                           Яндекс      Старший разработчик
# 4           2     0            University at Buffalo                 Аспирант
# ..        ...   ...                              ...                      ...
# 137        84     2          Т-банк Центр Разработки      Старший BI аналитик
# 138        85     0                             РСТИ                 Аналитик
# 139        86     0        Vattenfall Energy Trading    Junior Options Trader
# 140        87     0  Пивоваренная компания «Балтика»            Demand planer
# 141        87     1              ООО Мултон Партнерс            Demand planer
#
#                     salary_range  graduation_year math_group  \
# 0     50 000 руб. — 100 000 руб.             2019         Да
# 1    150 000 руб. — 200 000 руб.             2019         Да
# 2    300 000 руб. — 350 000 руб.             2019         Да
# 3             Более 400 000 руб.             2019         Да
# 4                           None             2019         Да
# ..                           ...              ...        ...
# 137  200 000 руб. — 250 000 руб.             2020         Да
# 138  200 000 руб. — 250 000 руб.             2017         Да
# 139           Более 400 000 руб.             2019        Нет
# 140  100 000 руб. — 150 000 руб.             2018         Да
# 141  150 000 руб. — 200 000 руб.             2018         Да
#
#               magistracy
# 0       Без магистратуры
# 1       Без магистратуры
# 2       Без магистратуры
# 3       Без магистратуры
# 4    Другая магистратура
# ..                   ...
# 137     Без магистратуры
# 138  Другая магистратура
# 139     Без магистратуры
# 140  Другая магистратура
# 141  Другая магистратура
#
# [142 rows x 8 columns]

# %%
data.groupby(["graduation_year", "company"]).agg(agg_data=("graduate", "count"))
# Out:
#                                        agg_data
# graduation_year company
# 2016                                          2
#                 АК «АЛРОСА» (ПАО)             1
#                 ПАО "Газпром нефть"           2
# 2017            AdVenture                     1
#                 AppQuantum                    1
# ...                                         ...
# 2024            Астех Индастриз               1
#                 Газстройпром                  1
#                 ООО "Газпром ВНИИГАЗ"         1
#                 ООО "Гротекс"                 1
#                 ООО "Контакт"                 1
#
# [123 rows x 1 columns]
